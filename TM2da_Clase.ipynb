# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#pip install opencv-python

# %%
strImg = "p.jpg"
img = cv2.imread(strImg, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img, cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-47d1747155f5> in <module>()
#       1
# ----> 2 plt.imshow(img, cmap="gray")
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
alto = img.shape[0]
ancho= img.shape[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7708cb1df437> in <module>()
# ----> 1 alto = img.shape[0]
#       2 ancho= img.shape[1]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
ecualizeImg = np.zeros((alto, ancho, 1)) #salida en escala de grises
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-62cc80d1fd3d> in <module>()
# ----> 1 ecualizeImg = np.zeros((alto, ancho, 1)) #salida en escala de grises
#
# NameError: name 'alto' is not defined

# %%
intensidades = range(0, 256)
frecuencia =np.zero((256))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4f821ebdd32b> in <module>()
#       1 intensidades = range(0, 256)
# ----> 2 frecuencia =np.zero((256))
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'zero'

# %%
for i in range(0, alto):
  for j in range(0, ancho):
    pixel = img[i, j]
    frecuencias[pixel] = frecuencias[pixel] + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2b353182b72f> in <module>()
# ----> 1 for i in range(0, alto):
#       2   for j in range(0, ancho):
#       3     pixel = img[i, j]
#       4     frecuencias[pixel] = frecuencias[pixel] + 1
#
# NameError: name 'alto' is not defined

# %%
densidad = np.true_divide(frecuencias, (alto*ancho)) # calculamos densidad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5b6fe4795509> in <module>()
# ----> 1 densidad = np.true_divide(frecuencias, (alto*ancho)) # calculamos densidad
#
# NameError: name 'frecuencias' is not defined

# %%
#CDF
cdfDensidad = np.cumsum(densidad, dtype=float)

# %%
for i in range(0, alto):
  for j in range(0, ancho):
    pixel = img[i, j]
    newPixel = 255*cdfDensidad[pixel] #ecualizacion
    ecualizacion

# %% [markdown]
# para ver ambas imagenes de lado a lado

# %%
f, axarr = plt.subplots(1, 2)
axarr[0].imshow(img, cmap='gray')
axarr[1].imshow(ecualizeImg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-afa55c31953f> in <module>()
#       1 f, axarr = plt.subplots(1, 2)
# ----> 2 axarr[0].imshow(img, cmap='gray')
#       3 axarr[1].imshow(ecualizeImg, cmap='gray')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
# ...

# %%
##Histograms
hist1 = cv2.calcHist ([img], [0], None, [256], [0,256])
plt.plot(hist2, color= "gray")
plt.xlabel("Intensidad de Pixel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-26596b1d5c06> in <module>()
#       1 ##Histograms
#       2 hist1 = cv2.calcHist ([img], [0], None, [256], [0,256])
# ----> 3 plt.plot(hist2, color= "gray")
#       4 plt.xlabel("Intensidad de Pixel")
#
# NameError: name 'hist2' is not defined

# %% [markdown]
# ##leer imagen

# %%
from IPython.display import Image
Image(filename='HSV.JPG')
